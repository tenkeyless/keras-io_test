# %% [markdown]
# # 커스텀 콜백 작성하기

# %% [markdown]
# **저자:** Rick Chao, Francois Chollet
# **생성일:** 2019/03/20
# **최종편집일:** 2023/06/25
# **설명:** Keras에서 새로운 콜백을 작성하는 완벽한 가이드

# %%
# 이 노트북은 Keras 3이 설치되어 있다는 가정 하에 진행됩니다.
#
# !pip install keras --upgrade --quiet

# %%
import numpy as np
import os

os.environ["KERAS_BACKEND"] = "jax"

# %%
from keras import backend
print(backend.backend())
# Out:
# jax

# %%
import keras
keras.__version__
# Out:
# '3.4.1'

# %% [markdown]
# ## 소개

# %% [markdown]
# 콜백(callback)은 Keras 모델의 트레이닝, 평가, 또는 추론 중에 동작을 커스터마이즈할 수 있는 강력한 도구입니다.
# 예를 들어, [`keras.callbacks.TensorBoard`](https://codecompose7.github.io/keras-doc-kr.github.io/api/callbacks/tensorboard#tensorboard-class)는 TensorBoard로 트레이닝 진행 상황과 결과를 시각화하고,
# [`keras.callbacks.ModelCheckpoint`](https://codecompose7.github.io/keras-doc-kr.github.io/api/callbacks/model_checkpoint#modelcheckpoint-class)는 트레이닝 중 주기적으로 모델을 저장합니다.
#
# 이 가이드에서는 Keras 콜백이 무엇인지, 무엇을 할 수 있는지,
# 그리고 어떻게 직접 콜백을 작성할 수 있는지 배우게 됩니다.
# 간단한 콜백 애플리케이션의 예시를 제공하여 시작할 수 있도록 도와드립니다.

# %% [markdown]
# ## 셋업

# %%
import numpy as np
import keras

# %% [markdown]
# ## Keras 콜백 개요

# %% [markdown]
# 모든 콜백은 [`keras.callbacks.Callback`](https://codecompose7.github.io/keras-doc-kr.github.io/api/callbacks/base_callback#callback-class) 클래스를 서브클래싱(subclass)하며,
# 트레이닝, 테스트, 예측의 다양한 단계에서 호출되는 일련의 메서드를 오버라이드합니다.
# 콜백은 트레이닝 중에 모델의 내부 상태와 통계를 확인하는 데 유용합니다.
#
# 다음 모델 메서드에 `callbacks`라는 키워드 인자로 콜백 리스트를 전달할 수 있습니다:
#
# -   `keras.Model.fit()`
# -   `keras.Model.evaluate()`
# -   `keras.Model.predict()`

# %% [markdown]
# ## 콜백 메서드 개요

# %% [markdown]
# ### Global 메서드

# %% [markdown]
# #### `on_(train|test|predict)_begin(self, logs=None)`

# %% [markdown]
# `fit`/`evaluate`/`predict` 시작 시 호출됩니다.

# %% [markdown]
# #### `on_(train|test|predict)_end(self, logs=None)`

# %% [markdown]
# `fit`/`evaluate`/`predict` 종료 시 호출됩니다.

# %% [markdown]
# ### 트레이닝/테스트/예측을 위한 배치 레벨 메서드

# %% [markdown]
# #### `on_(train|test|predict)_batch_begin(self, batch, logs=None)`

# %% [markdown]
# 트레이닝/테스트/예측 중 배치 처리를 시작하기 직전에 호출됩니다.

# %% [markdown]
# #### `on_(train|test|predict)_batch_end(self, batch, logs=None)`

# %% [markdown]
# 배치 트레이닝/테스트/예측이 완료된 후 호출됩니다.
# 이 메서드 내에서 `logs`는 메트릭 결과를 포함하는 딕셔너리입니다.

# %% [markdown]
# ### 에포크 레벨 메서드 (트레이닝 전용)

# %% [markdown]
# #### `on_epoch_begin(self, epoch, logs=None)`

# %% [markdown]
# 트레이닝 중 에포크가 시작될 때 호출됩니다.

# %% [markdown]
# #### `on_epoch_end(self, epoch, logs=None)`

# %% [markdown]
# 트레이닝 중 에포크가 끝날 때 호출됩니다.

# %% [markdown]
# ## 기본 예제

# %% [markdown]
# 구체적인 예시를 살펴보겠습니다.
# 먼저, TensorFlow를 임포트하고 간단한 Sequential Keras 모델을 정의해봅시다:

# %%
# 콜백을 추가할 Keras 모델 정의
def get_model():
    model = keras.Sequential()
    model.add(keras.layers.Dense(1))
    model.compile(
        optimizer=keras.optimizers.RMSprop(learning_rate=0.1),
        loss="mean_squared_error",
        metrics=["mean_absolute_error"],
    )
    return model

# %% [markdown]
# 그런 다음, Keras 데이터셋 API를 사용하여 트레이닝 및 테스트용 MNIST 데이터를 로드합니다:

# %%
# 예시 MNIST 데이터를 로드하고 전처리합니다.
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

# 데이터를 1000개의 샘플로 제한합니다.
x_train = x_train[:1000]
y_train = y_train[:1000]
x_test = x_test[:1000]
y_test = y_test[:1000]

# %% [markdown]
# 이제, 다음을 로그하는 간단한 커스텀 콜백을 정의해봅시다:
#
# -   `fit`/`evaluate`/`predict`가 시작하고 끝날 때
# -   각 에포크가 시작하고 끝날 때
# -   각 트레이닝 배치가 시작하고 끝날 때
# -   각 평가(테스트) 배치가 시작하고 끝날 때
# -   각 추론(예측) 배치가 시작하고 끝날 때

# %%
class CustomCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        keys = list(logs.keys())
        print("Starting training; got log keys: {}".format(keys))

    def on_train_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop training; got log keys: {}".format(keys))

    def on_epoch_begin(self, epoch, logs=None):
        keys = list(logs.keys())
        print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.keys())
        print("End epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_test_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start testing; got log keys: {}".format(keys))

    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop testing; got log keys: {}".format(keys))

    def on_predict_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start predicting; got log keys: {}".format(keys))

    def on_predict_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop predicting; got log keys: {}".format(keys))

    def on_train_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: start of batch {}; got log keys: {}".format(batch, keys))

    def on_train_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: end of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: start of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: end of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: start of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: end of batch {}; got log keys: {}".format(batch, keys))

# %% [markdown]
# 한번 실행해봅시다:

# %%
model = get_model()
model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=1,
    verbose=0,
    validation_split=0.5,
    callbacks=[CustomCallback()],
)

res = model.evaluate(
    x_test, y_test, batch_size=128, verbose=0, callbacks=[CustomCallback()]
)

res = model.predict(x_test, batch_size=128, callbacks=[CustomCallback()])
# Out:
# Starting training; got log keys: []
# Start epoch 0 of training; got log keys: []
# ...Training: start of batch 0; got log keys: []
# ...Training: end of batch 0; got log keys: ['loss', 'mean_absolute_error']
# ...Training: start of batch 1; got log keys: []
# ...Training: end of batch 1; got log keys: ['loss', 'mean_absolute_error']
# ...Training: start of batch 2; got log keys: []
# ...Training: end of batch 2; got log keys: ['loss', 'mean_absolute_error']
# ...Training: start of batch 3; got log keys: []
# ...Training: end of batch 3; got log keys: ['loss', 'mean_absolute_error']
# Start testing; got log keys: []
# ...Evaluating: start of batch 0; got log keys: []
# ...Evaluating: end of batch 0; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 1; got log keys: []
# ...Evaluating: end of batch 1; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 2; got log keys: []
# ...Evaluating: end of batch 2; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 3; got log keys: []
# ...Evaluating: end of batch 3; got log keys: ['loss', 'mean_absolute_error']
# Stop testing; got log keys: ['loss', 'mean_absolute_error']
# End epoch 0 of training; got log keys: ['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error']
# Stop training; got log keys: ['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error']
# Start testing; got log keys: []
# ...Evaluating: start of batch 0; got log keys: []
# ...Evaluating: end of batch 0; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 1; got log keys: []
# ...Evaluating: end of batch 1; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 2; got log keys: []
# ...Evaluating: end of batch 2; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 3; got log keys: []
# ...Evaluating: end of batch 3; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 4; got log keys: []
# ...Evaluating: end of batch 4; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 5; got log keys: []
# ...Evaluating: end of batch 5; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 6; got log keys: []
# ...Evaluating: end of batch 6; got log keys: ['loss', 'mean_absolute_error']
# ...Evaluating: start of batch 7; got log keys: []
# ...Evaluating: end of batch 7; got log keys: ['loss', 'mean_absolute_error']
# Stop testing; got log keys: ['loss', 'mean_absolute_error']
# Start predicting; got log keys: []
# ...Predicting: start of batch 0; got log keys: []
# ...Predicting: end of batch 0; got log keys: ['outputs']
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step...Predicting: start of batch 1; got log keys: []
# ...Predicting: end of batch 1; got log keys: ['outputs']
# ...Predicting: start of batch 2; got log keys: []
# ...Predicting: end of batch 2; got log keys: ['outputs']
# ...Predicting: start of batch 3; got log keys: []
# ...Predicting: end of batch 3; got log keys: ['outputs']
# ...Predicting: start of batch 4; got log keys: []
# ...Predicting: end of batch 4; got log keys: ['outputs']
# ...Predicting: start of batch 5; got log keys: []
# ...Predicting: end of batch 5; got log keys: ['outputs']
# ...Predicting: start of batch 6; got log keys: []
# ...Predicting: end of batch 6; got log keys: ['outputs']
# ...Predicting: start of batch 7; got log keys: []
# ...Predicting: end of batch 7; got log keys: ['outputs']
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/stepStop predicting; got log keys: []
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### `logs` 딕셔너리의 사용

# %% [markdown]
# `logs` 딕셔너리는 배치나 에포크가 끝날 때 손실 값과 모든 메트릭을 포함합니다.
# 예시로는 손실 값과 평균 절대 오차(mean absolute error)가 있습니다.

# %%
class LossAndErrorPrintingCallback(keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_test_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_epoch_end(self, epoch, logs=None):
        print(
            "The average loss for epoch {} is {:7.2f} "
            "and mean absolute error is {:7.2f}.".format(
                epoch, logs["loss"], logs["mean_absolute_error"]
            )
        )


model = get_model()
model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=2,
    verbose=0,
    callbacks=[LossAndErrorPrintingCallback()],
)

res = model.evaluate(
    x_test,
    y_test,
    batch_size=128,
    verbose=0,
    callbacks=[LossAndErrorPrintingCallback()],
)
# Out:
# Up to batch 0, the average loss is   23.96.
# Up to batch 1, the average loss is  476.87.
# Up to batch 2, the average loss is  327.16.
# Up to batch 3, the average loss is  248.04.
# Up to batch 4, the average loss is  199.97.
# Up to batch 5, the average loss is  167.77.
# Up to batch 6, the average loss is  144.58.
# Up to batch 7, the average loss is  130.01.
# The average loss for epoch 0 is  130.01 and mean absolute error is    6.13.
# Up to batch 0, the average loss is    4.97.
# Up to batch 1, the average loss is    4.54.
# Up to batch 2, the average loss is    4.74.
# Up to batch 3, the average loss is    4.81.
# Up to batch 4, the average loss is    4.66.
# Up to batch 5, the average loss is    4.68.
# Up to batch 6, the average loss is    4.60.
# Up to batch 7, the average loss is    4.66.
# The average loss for epoch 1 is    4.66 and mean absolute error is    1.76.
# Up to batch 0, the average loss is    6.93.
# Up to batch 1, the average loss is    6.29.
# Up to batch 2, the average loss is    6.38.
# Up to batch 3, the average loss is    6.42.
# Up to batch 4, the average loss is    6.66.
# Up to batch 5, the average loss is    6.56.
# Up to batch 6, the average loss is    6.52.
# Up to batch 7, the average loss is    6.46.

# %% [markdown]
# ## `self.model` 속성의 사용

# %% [markdown]
# 메서드가 호출될 때 로그 정보를 받는 것 외에도,
# 콜백은 현재 트레이닝/평가/추론 라운드와 연결된 모델인 `self.model`에 접근할 수 있습니다.
#
# 콜백에서 `self.model`을 사용하여 할 수 있는 몇 가지 예는 다음과 같습니다:
#
# -   `self.model.stop_training = True`를 설정하여, 트레이닝을 즉시 중단할 수 있습니다.
# -   옵티마이저(`self.model.optimizer`로서 사용가능)의 하이퍼파라미터(예: `self.model.optimizer.learning_rate`)를 변경할 수 있습니다.
# -   주기적으로 모델을 저장할 수 있습니다.
# -   에포크가 끝날 때 몇 가지 테스트 샘플에 대해 `model.predict()`의 출력을 기록하여, 트레이닝 중 검증(sanity check)할 수 있습니다.
# -   에포크가 끝날 때 중간 특성의 시각화를 추출하여, 모델이 학습하는 내용을 모니터링할 수 있습니다.
# -   기타 등등.
#
# 몇 가지 예시를 통해 이를 실제로 확인해보겠습니다.

# %% [markdown]
# ## Keras 콜백 애플리케이션 예시

# %% [markdown]
# ### 최소 손실에서의 조기 종료

# %% [markdown]
# 첫 번째 예시는 손실의 최소값에 도달하면 트레이닝을 중지하는 `Callback`을 생성하는 방법을 보여줍니다.
# 이때 `self.model.stop_training` (boolean) 속성을 설정합니다.
# 선택적으로, `patience`라는 인자를 제공하여 로컬 최소값에 도달한 후,
# 몇 에포크 동안 대기한 뒤 트레이닝을 중지할지 지정할 수 있습니다.
#
# [`keras.callbacks.EarlyStopping`](https://codecompose7.github.io/keras-doc-kr.github.io/api/callbacks/early_stopping#earlystopping-class)는 더 완전하고 일반적인 구현을 제공합니다.

# %%
class EarlyStoppingAtMinLoss(keras.callbacks.Callback):
    """손실이 최소값에 도달하면 트레이닝을 중지합니다, 즉 손실이 더 이상 감소하지 않을 때.

    Arguments:
        patience: 최소값에 도달한 후 대기할 에포크 수.
            개선되지 않은 상태에서 지정된 에포크 수가 지나면, 트레이닝이 중지됩니다.
    """

    def __init__(self, patience=0):
        super().__init__()
        self.patience = patience
        # 최소 손실이 발생한 지점에서의 가중치를 저장하기 위한 best_weights.
        self.best_weights = None

    def on_train_begin(self, logs=None):
        # 손실이 더 이상 최소가 아닐 때 기다린 에포크 수.
        self.wait = 0
        # 트레이닝이 중지되는 에포크.
        self.stopped_epoch = 0
        # 초기값을 무한대로 설정.
        self.best = np.inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get("loss")
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            # 현재 결과가 더 좋으면(작으면) 최상의 가중치를 기록합니다.
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("최상의 에포크 끝에서 모델 가중치를 복원합니다.")
                self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print(f"Epoch {self.stopped_epoch + 1}: 조기 종료")


model = get_model()
model.fit(
    x_train,
    y_train,
    batch_size=64,
    epochs=30,
    verbose=0,
    callbacks=[LossAndErrorPrintingCallback(), EarlyStoppingAtMinLoss()],
)
# Out:
# Up to batch 0, the average loss is   25.53.
# Up to batch 1, the average loss is  420.73.
# Up to batch 2, the average loss is  290.23.
# Up to batch 3, the average loss is  220.76.
# Up to batch 4, the average loss is  178.19.
# Up to batch 5, the average loss is  149.42.
# Up to batch 6, the average loss is  128.94.
# Up to batch 7, the average loss is  113.40.
# Up to batch 8, the average loss is  101.30.
# Up to batch 9, the average loss is   91.57.
# Up to batch 10, the average loss is   83.72.
# Up to batch 11, the average loss is   77.08.
# Up to batch 12, the average loss is   71.63.
# Up to batch 13, the average loss is   66.80.
# Up to batch 14, the average loss is   62.66.
# Up to batch 15, the average loss is   60.38.
# The average loss for epoch 0 is   60.38 and mean absolute error is    3.85.
# Up to batch 0, the average loss is    8.10.
# Up to batch 1, the average loss is    7.78.
# Up to batch 2, the average loss is   10.37.
# Up to batch 3, the average loss is   21.31.
# Up to batch 4, the average loss is   43.52.
# Up to batch 5, the average loss is   58.22.
# Up to batch 6, the average loss is   57.29.
# Up to batch 7, the average loss is   52.23.
# Up to batch 8, the average loss is   47.56.
# Up to batch 9, the average loss is   43.53.
# Up to batch 10, the average loss is   40.14.
# Up to batch 11, the average loss is   37.26.
# Up to batch 12, the average loss is   34.70.
# Up to batch 13, the average loss is   32.49.
# Up to batch 14, the average loss is   30.71.
# Up to batch 15, the average loss is   29.66.
# The average loss for epoch 1 is   29.66 and mean absolute error is    3.91.
# Up to batch 0, the average loss is    4.38.
# Up to batch 1, the average loss is    3.64.
# Up to batch 2, the average loss is    3.69.
# Up to batch 3, the average loss is    3.62.
# Up to batch 4, the average loss is    3.75.
# Up to batch 5, the average loss is    3.87.
# Up to batch 6, the average loss is    4.62.
# Up to batch 7, the average loss is    8.71.
# Up to batch 8, the average loss is   21.79.
# Up to batch 9, the average loss is   38.88.
# Up to batch 10, the average loss is   43.20.
# Up to batch 11, the average loss is   42.10.
# Up to batch 12, the average loss is   40.24.
# Up to batch 13, the average loss is   38.20.
# Up to batch 14, the average loss is   36.13.
# Up to batch 15, the average loss is   34.95.
# The average loss for epoch 2 is   34.95 and mean absolute error is    4.13.
# 최상의 에포크 끝에서 모델 가중치를 복원합니다.
# Epoch 3: 조기 종료

# %% [markdown]
# ### 학습률 스케줄링

# %% [markdown]
# 이 예시에서는, 커스텀 콜백을 사용하여 트레이닝 과정에서 옵티마이저의 학습률을 동적으로 변경하는 방법을 보여줍니다.
#
# 일반적인 구현을 위해서는 `callbacks.LearningRateScheduler`를 참고하세요.

# %%
class CustomLearningRateScheduler(keras.callbacks.Callback):
    """스케줄에 따라 학습률을 설정하는 학습률 스케줄러.

    Arguments:
        schedule: 에포크 인덱스(정수, 0부터 시작)와 현재 학습률을 입력으로 받아 새로운 학습률(float)을 출력으로 반환하는 함수.
    """

    def __init__(self, schedule):
        super().__init__()
        self.schedule = schedule

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, "learning_rate"):
            raise ValueError('Optimizer에는 "learning_rate" 속성이 있어야 합니다.')
        # 모델의 옵티마이저에서 현재 학습률을 가져옵니다.
        lr = self.model.optimizer.learning_rate
        # 스케줄 함수 호출하여 스케줄된 학습률을 가져옵니다.
        scheduled_lr = self.schedule(epoch, lr)
        # 이 에포크가 시작되기 전에 옵티마이저에 값 설정.
        self.model.optimizer.learning_rate = scheduled_lr
        print(f"\n에포크 {epoch}: 학습률은 {float(np.array(scheduled_lr))}입니다.")


LR_SCHEDULE = [
    # (시작 할 에포크, 학습률) 튜플
    (3, 0.05),
    (6, 0.01),
    (9, 0.005),
    (12, 0.001),
]


def lr_schedule(epoch, lr):
    """에포크에 기반하여 스케줄된 학습률을 가져오는 헬퍼 함수."""
    if epoch < LR_SCHEDULE[0][0] or epoch > LR_SCHEDULE[-1][0]:
        return lr
    for i in range(len(LR_SCHEDULE)):
        if epoch == LR_SCHEDULE[i][0]:
            return LR_SCHEDULE[i][1]
    return lr


model = get_model()
model.fit(
    x_train,
    y_train,
    batch_size=64,
    epochs=15,
    verbose=0,
    callbacks=[
        LossAndErrorPrintingCallback(),
        CustomLearningRateScheduler(lr_schedule),
    ],
)
# Out:
# 에포크 0: 학습률은 0.10000000149011612입니다.
# Up to batch 0, the average loss is   40.08.
# Up to batch 1, the average loss is  435.03.
# Up to batch 2, the average loss is  300.08.
# Up to batch 3, the average loss is  227.27.
# Up to batch 4, the average loss is  183.11.
# Up to batch 5, the average loss is  154.03.
# Up to batch 6, the average loss is  132.87.
# Up to batch 7, the average loss is  117.12.
# Up to batch 8, the average loss is  104.65.
# Up to batch 9, the average loss is   94.74.
# Up to batch 10, the average loss is   86.53.
# Up to batch 11, the average loss is   79.79.
# Up to batch 12, the average loss is   74.08.
# Up to batch 13, the average loss is   69.14.
# Up to batch 14, the average loss is   64.85.
# Up to batch 15, the average loss is   62.51.
# The average loss for epoch 0 is   62.51 and mean absolute error is    3.99.
#
# 에포크 1: 학습률은 0.10000000149011612입니다.
# Up to batch 0, the average loss is    8.27.
# Up to batch 1, the average loss is   10.80.
# Up to batch 2, the average loss is   15.52.
# Up to batch 3, the average loss is   22.45.
# Up to batch 4, the average loss is   33.27.
# Up to batch 5, the average loss is   42.34.
# Up to batch 6, the average loss is   44.40.
# Up to batch 7, the average loss is   44.03.
# Up to batch 8, the average loss is   43.44.
# Up to batch 9, the average loss is   42.35.
# Up to batch 10, the average loss is   40.19.
# Up to batch 11, the average loss is   38.21.
# Up to batch 12, the average loss is   36.75.
# Up to batch 13, the average loss is   35.35.
# Up to batch 14, the average loss is   34.18.
# Up to batch 15, the average loss is   33.52.
# The average loss for epoch 1 is   33.52 and mean absolute error is    4.89.
#
# 에포크 2: 학습률은 0.10000000149011612입니다.
# Up to batch 0, the average loss is   16.67.
# Up to batch 1, the average loss is   19.08.
# Up to batch 2, the average loss is   21.04.
# Up to batch 3, the average loss is   24.43.
# Up to batch 4, the average loss is   28.37.
# Up to batch 5, the average loss is   33.74.
# Up to batch 6, the average loss is   37.16.
# Up to batch 7, the average loss is   37.25.
# Up to batch 8, the average loss is   35.91.
# Up to batch 9, the average loss is   34.53.
# Up to batch 10, the average loss is   33.71.
# Up to batch 11, the average loss is   33.94.
# Up to batch 12, the average loss is   34.70.
# Up to batch 13, the average loss is   34.42.
# Up to batch 14, the average loss is   33.97.
# Up to batch 15, the average loss is   33.48.
# The average loss for epoch 2 is   33.48 and mean absolute error is    5.11.
#
# 에포크 3: 학습률은 0.05입니다.
# Up to batch 0, the average loss is   22.53.
# Up to batch 1, the average loss is   13.64.
# Up to batch 2, the average loss is   10.22.
# Up to batch 3, the average loss is    8.49.
# Up to batch 4, the average loss is    7.33.
# Up to batch 5, the average loss is    6.72.
# Up to batch 6, the average loss is    6.47.
# Up to batch 7, the average loss is    6.26.
# Up to batch 8, the average loss is    5.94.
# Up to batch 9, the average loss is    5.79.
# Up to batch 10, the average loss is    5.63.
# Up to batch 11, the average loss is    5.44.
# Up to batch 12, the average loss is    5.32.
# Up to batch 13, the average loss is    5.17.
# Up to batch 14, the average loss is    5.06.
# Up to batch 15, the average loss is    4.99.
# The average loss for epoch 3 is    4.99 and mean absolute error is    1.70.
#
# 에포크 4: 학습률은 0.05000000074505806입니다.
# Up to batch 0, the average loss is    3.01.
# Up to batch 1, the average loss is    3.36.
# Up to batch 2, the average loss is    3.46.
# Up to batch 3, the average loss is    3.60.
# Up to batch 4, the average loss is    3.79.
# Up to batch 5, the average loss is    4.13.
# Up to batch 6, the average loss is    5.19.
# Up to batch 7, the average loss is    7.46.
# Up to batch 8, the average loss is    9.95.
# Up to batch 9, the average loss is   11.31.
# Up to batch 10, the average loss is   11.81.
# Up to batch 11, the average loss is   11.71.
# Up to batch 12, the average loss is   11.26.
# Up to batch 13, the average loss is   10.72.
# Up to batch 14, the average loss is   10.25.
# Up to batch 15, the average loss is   10.03.
# The average loss for epoch 4 is   10.03 and mean absolute error is    2.47.
#
# 에포크 5: 학습률은 0.05000000074505806입니다.
# Up to batch 0, the average loss is    8.61.
# Up to batch 1, the average loss is    7.97.
# Up to batch 2, the average loss is    8.10.
# Up to batch 3, the average loss is    8.77.
# Up to batch 4, the average loss is    9.75.
# Up to batch 5, the average loss is   10.85.
# Up to batch 6, the average loss is   10.81.
# Up to batch 7, the average loss is   10.70.
# Up to batch 8, the average loss is   10.67.
# Up to batch 9, the average loss is   10.49.
# Up to batch 10, the average loss is   10.30.
# Up to batch 11, the average loss is   10.11.
# Up to batch 12, the average loss is   10.01.
# Up to batch 13, the average loss is    9.91.
# Up to batch 14, the average loss is    9.85.
# Up to batch 15, the average loss is    9.74.
# The average loss for epoch 5 is    9.74 and mean absolute error is    2.61.
#
# 에포크 6: 학습률은 0.01입니다.
# Up to batch 0, the average loss is   11.71.
# Up to batch 1, the average loss is    9.37.
# Up to batch 2, the average loss is    7.65.
# Up to batch 3, the average loss is    6.48.
# Up to batch 4, the average loss is    5.81.
# Up to batch 5, the average loss is    5.28.
# Up to batch 6, the average loss is    4.91.
# Up to batch 7, the average loss is    4.69.
# Up to batch 8, the average loss is    4.55.
# Up to batch 9, the average loss is    4.34.
# Up to batch 10, the average loss is    4.26.
# Up to batch 11, the average loss is    4.06.
# Up to batch 12, the average loss is    4.00.
# Up to batch 13, the average loss is    3.95.
# Up to batch 14, the average loss is    3.93.
# Up to batch 15, the average loss is    3.90.
# The average loss for epoch 6 is    3.90 and mean absolute error is    1.51.
#
# 에포크 7: 학습률은 0.009999999776482582입니다.
# Up to batch 0, the average loss is    2.87.
# Up to batch 1, the average loss is    2.97.
# Up to batch 2, the average loss is    2.70.
# Up to batch 3, the average loss is    2.72.
# Up to batch 4, the average loss is    2.63.
# Up to batch 5, the average loss is    2.58.
# Up to batch 6, the average loss is    2.75.
# Up to batch 7, the average loss is    2.85.
# Up to batch 8, the average loss is    2.85.
# Up to batch 9, the average loss is    3.00.
# Up to batch 10, the average loss is    2.99.
# Up to batch 11, the average loss is    2.94.
# Up to batch 12, the average loss is    2.93.
# Up to batch 13, the average loss is    2.92.
# Up to batch 14, the average loss is    2.93.
# Up to batch 15, the average loss is    2.97.
# The average loss for epoch 7 is    2.97 and mean absolute error is    1.33.
#
# 에포크 8: 학습률은 0.009999999776482582입니다.
# Up to batch 0, the average loss is    2.76.
# Up to batch 1, the average loss is    2.75.
# Up to batch 2, the average loss is    2.82.
# Up to batch 3, the average loss is    2.73.
# Up to batch 4, the average loss is    2.71.
# Up to batch 5, the average loss is    2.87.
# Up to batch 6, the average loss is    2.86.
# Up to batch 7, the average loss is    3.02.
# Up to batch 8, the average loss is    2.94.
# Up to batch 9, the average loss is    2.98.
# Up to batch 10, the average loss is    2.98.
# Up to batch 11, the average loss is    2.97.
# Up to batch 12, the average loss is    3.05.
# Up to batch 13, the average loss is    3.02.
# Up to batch 14, the average loss is    3.00.
# Up to batch 15, the average loss is    3.05.
# The average loss for epoch 8 is    3.05 and mean absolute error is    1.35.
#
# 에포크 9: 학습률은 0.005입니다.
# Up to batch 0, the average loss is    2.93.
# Up to batch 1, the average loss is    2.93.
# Up to batch 2, the average loss is    2.60.
# Up to batch 3, the average loss is    3.05.
# Up to batch 4, the average loss is    3.00.
# Up to batch 5, the average loss is    3.01.
# Up to batch 6, the average loss is    2.95.
# Up to batch 7, the average loss is    2.83.
# Up to batch 8, the average loss is    2.86.
# Up to batch 9, the average loss is    2.83.
# Up to batch 10, the average loss is    2.90.
# Up to batch 11, the average loss is    2.87.
# Up to batch 12, the average loss is    2.88.
# Up to batch 13, the average loss is    2.90.
# Up to batch 14, the average loss is    2.84.
# Up to batch 15, the average loss is    2.83.
# The average loss for epoch 9 is    2.83 and mean absolute error is    1.30.
#
# 에포크 10: 학습률은 0.004999999888241291입니다.
# Up to batch 0, the average loss is    2.33.
# Up to batch 1, the average loss is    2.93.
# Up to batch 2, the average loss is    2.75.
# Up to batch 3, the average loss is    2.57.
# Up to batch 4, the average loss is    2.50.
# Up to batch 5, the average loss is    2.60.
# Up to batch 6, the average loss is    2.60.
# Up to batch 7, the average loss is    2.61.
# Up to batch 8, the average loss is    2.59.
# Up to batch 9, the average loss is    2.61.
# Up to batch 10, the average loss is    2.64.
# Up to batch 11, the average loss is    2.63.
# Up to batch 12, the average loss is    2.66.
# Up to batch 13, the average loss is    2.69.
# Up to batch 14, the average loss is    2.76.
# Up to batch 15, the average loss is    2.75.
# The average loss for epoch 10 is    2.75 and mean absolute error is    1.28.
#
# 에포크 11: 학습률은 0.004999999888241291입니다.
# Up to batch 0, the average loss is    2.00.
# Up to batch 1, the average loss is    2.48.
# Up to batch 2, the average loss is    2.84.
# Up to batch 3, the average loss is    2.65.
# Up to batch 4, the average loss is    2.65.
# Up to batch 5, the average loss is    2.54.
# Up to batch 6, the average loss is    2.80.
# Up to batch 7, the average loss is    2.79.
# Up to batch 8, the average loss is    2.81.
# Up to batch 9, the average loss is    2.74.
# Up to batch 10, the average loss is    2.72.
# Up to batch 11, the average loss is    2.74.
# Up to batch 12, the average loss is    2.77.
# Up to batch 13, the average loss is    2.76.
# Up to batch 14, the average loss is    2.71.
# Up to batch 15, the average loss is    2.68.
# The average loss for epoch 11 is    2.68 and mean absolute error is    1.26.
#
# 에포크 12: 학습률은 0.001입니다.
# Up to batch 0, the average loss is    2.19.
# Up to batch 1, the average loss is    2.23.
# Up to batch 2, the average loss is    2.32.
# Up to batch 3, the average loss is    2.26.
# Up to batch 4, the average loss is    2.28.
# Up to batch 5, the average loss is    2.18.
# Up to batch 6, the average loss is    2.29.
# Up to batch 7, the average loss is    2.46.
# Up to batch 8, the average loss is    2.40.
# Up to batch 9, the average loss is    2.43.
# Up to batch 10, the average loss is    2.45.
# Up to batch 11, the average loss is    2.53.
# Up to batch 12, the average loss is    2.57.
# Up to batch 13, the average loss is    2.63.
# Up to batch 14, the average loss is    2.64.
# Up to batch 15, the average loss is    2.61.
# The average loss for epoch 12 is    2.61 and mean absolute error is    1.23.
#
# 에포크 13: 학습률은 0.0010000000474974513입니다.
# Up to batch 0, the average loss is    3.44.
# Up to batch 1, the average loss is    2.83.
# Up to batch 2, the average loss is    2.63.
# Up to batch 3, the average loss is    2.80.
# Up to batch 4, the average loss is    2.71.
# Up to batch 5, the average loss is    2.69.
# Up to batch 6, the average loss is    2.81.
# Up to batch 7, the average loss is    2.79.
# Up to batch 8, the average loss is    2.69.
# Up to batch 9, the average loss is    2.70.
# Up to batch 10, the average loss is    2.66.
# Up to batch 11, the average loss is    2.68.
# Up to batch 12, the average loss is    2.65.
# Up to batch 13, the average loss is    2.69.
# Up to batch 14, the average loss is    2.63.
# Up to batch 15, the average loss is    2.60.
# The average loss for epoch 13 is    2.60 and mean absolute error is    1.23.
#
# 에포크 14: 학습률은 0.0010000000474974513입니다.
# Up to batch 0, the average loss is    2.72.
# Up to batch 1, the average loss is    2.84.
# Up to batch 2, the average loss is    3.03.
# Up to batch 3, the average loss is    2.74.
# Up to batch 4, the average loss is    2.80.
# Up to batch 5, the average loss is    2.72.
# Up to batch 6, the average loss is    2.75.
# Up to batch 7, the average loss is    2.78.
# Up to batch 8, the average loss is    2.68.
# Up to batch 9, the average loss is    2.73.
# Up to batch 10, the average loss is    2.68.
# Up to batch 11, the average loss is    2.69.
# Up to batch 12, the average loss is    2.66.
# Up to batch 13, the average loss is    2.62.
# Up to batch 14, the average loss is    2.62.
# Up to batch 15, the average loss is    2.60.
# The average loss for epoch 14 is    2.60 and mean absolute error is    1.23.

# %% [markdown]
# ### Keras 내장 콜백

# %% [markdown]
# 기존 Keras 콜백들을 확인하려면 [API 문서](https://codecompose7.github.io/keras-doc-kr.github.io/api/callbacks/)를 참고하세요.
# 애플리케이션에는 CSV에 로그 기록, 모델 저장, TensorBoard에서 메트릭 시각화 등 다양한 기능이 포함됩니다!
